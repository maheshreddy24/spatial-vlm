# %%
dataset_F = load_dataset("HuggingFaceM4/the_cauldron", "vqav2", split="train")
dataset_F
# Out:
# ...
# Loading dataset shards:   0%|          | 0/27 [00:00<?, ?it/s]
# Dataset({
#     features: ['images', 'texts'],
#     num_rows: 82772
# })

# %%
from datasets import load_dataset

# ds = load_dataset("liuhaotian/LLaVA-Instruct-150K")
# dataset = load_dataset("HuggingFaceM4/the_cauldron", "vqav2", split="train")
# dataset = load_dataset("liuhaotian/LLaVA-Instruct-150K", split = 'train')
dataset = load_dataset("HuggingFaceM4/the_cauldron", "localized_narratives")
# Out:
# ...
# Loading dataset shards:   0%|          | 0/44 [00:00<?, ?it/s]

# %%
dataset_split = dataset['train'].train_test_split(test_size = 0.1)
dataset_split
# dataset_split
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['images', 'texts'],
#         num_rows: 179998
#     })
#     test: Dataset({
#         features: ['images', 'texts'],
#         num_rows: 20000
#     })
# })

# %%
dataset_split['train']
# Out:
# Dataset({
#     features: ['images', 'texts'],
#     num_rows: 179998
# })

# %%
from datasets import get_dataset_config_names
configs = get_dataset_config_names("liuhaotian/LLaVA-Instruct-150K")
print(configs)

# %%
dataset_food = load_dataset("mrdbourke/FoodExtract-1k-Vision")

# %%
dataset_food['train'][0]['image'].resize((512, 512))

# %%
for image, text in zip(dataset['images'], dataset['texts']):
    print(text[0])
    print(image[0].size)
    # break

# %%
dataset['texts'][80]

# %%
print(dataset['texts'][0])
dataset['images'][0][0]
